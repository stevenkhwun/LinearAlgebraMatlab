% %% [markdown]
% # MATLAB Notebook

% %% [markdown]
% ## This notebook is created in the MATLAB environment under Jupyter Lab.

% %% [markdown]
% For details, please refer to [MATLAB Integration for Jupyter](https://ww2.mathworks.cn/en/products/reference-architectures/jupyter.html)
%  and [Get the integration and documentation on GitHub](https://github.com/mathworks/jupyter-matlab-proxy).

% %% [markdown]
% ### MATLAB example 1

% %%
x = linspace(-2,3,100);
y = x.^2;
plot(x,y)
xlabel('x')
ylabel('y')
title('y = x^2')

% %% [markdown]
% ### MATLAB example 2
%
% The following example is extracted from the article [A Primer on Vector Autoregressions](https://notes.quantecon.org/submission/63629928d02e3100190d150b) published on QuantEcon Notes. The original Jupyter Notebook ('Primer_on_VARs.ipynb')has been downloaded and saved under the current folder.

% %%
load 'Data_USEconModel'

% %%
figure
subplot(3,1,1);
plot(DataTable.Time,DataTable.CPIAUCSL,'b');
title('CPI')
grid on
subplot(3,1,2);
plot(DataTable.Time,DataTable.UNRATE,'b');
title('Unemployment rate')
grid on
subplot(3,1,3);
plot(DataTable.Time,DataTable.TB3MS,'b');
title('3-mo T-bill')
grid on
