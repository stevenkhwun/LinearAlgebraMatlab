% %% [markdown]
% # Ploting $y=(x+1/x)^x$
%
% See the [link](https://uk.mathworks.com/help/matlab/ref/yline.html) for the use of the command `yline()`.
%
% For adding title and axis labels to chart, see this [link](https://uk.mathworks.com/help/matlab/creating_plots/add-title-axis-labels-and-legend-to-graph.html).
%
% This plot is initiated by the propsition 1.10 on page 9 in the book by [N. L. Carothers](https://s2pnd-matematika.fkip.unpatti.ac.id/wp-content/uploads/2019/03/N.-L.-Carothers-Real-analysis-Cambridge-University-Press-2000.pdf). This book is one of the recommendations by Gaurav Tiwari in his article [10 Best Real Analysis Books for Math Majors](https://gauravtiwari.org/10-best-real-analysis-books-for-math-majors/).

% %%
x = linspace(0, 10, 100);
y = (1 + 1./x).^x;
plot(x, y)
yline(exp(1), '-', {'$e$'}, 'Interpreter', 'latex')

% %%
x = linspace(0, 10, 100);
y = (1 + 1./x).^x;
plot(x, y)
yline(exp(1), '-', 'e')

% %%
set(gca, 'XAxisLocation', 'origin', 'YAxisLocation', 'origin')
x = linspace(0, 100, 100);
y = (1 + 1./x).^x;
plot(x, y)
yline(max(y), '-', 'e')

% %%
x = linspace(0, 10, 100);
y1 = (1 + 1./x);
figure
plot(x, y1)
hold on
y2 = (1 + 1./x).^x;
plot(x, y2)
yline(exp(1))
legend({'$1 + 1/x$', '$(1+1/x)^x$', '$e$'}, 'Interpreter', 'latex')
ax = gca;
ax.XAxisLocation = 'origin';
ax.YAxisLocation = 'origin';

% %% [markdown]
% # Ploting $y=e^{(-|x|+1)}$

% %%
x = linspace(-2, 2, 10000);
y3 = (exp(1)).^(-abs(x)+1);
figure
plot(x, y3)
yline(exp(1))
hold on
legend({'$e^{(-|x| + 1)}$', '$e$'}, 'Interpreter', 'latex')

% %%
x = linspace(0, 10, 10);
y3 = (exp(1)).^(x)
% Out:
% y3 = 1x10 double
% 	1.0e+04 *
%
%     0.0001    0.0003    0.0009    0.0028    0.0085    0.0259    0.0786    0.2387    0.7251    2.2026

% %%
hAx=axes;                      % a new axes
plot(randn(10,1))              % put some data on it...
yl=ylim;                       % get y-axis limits
pos=get(hAx,'position');       % and axes position vector
yrat=yl(end)/(yl(end)-yl(1));  % fractional position of origin relative y range
yht=yrat*pos(4);               % adjusted second axes height 
pos(2)=pos(2)+pos(4)-yht;      % new bottom is top position {pos(2)+pos(4)} less height
pos(4)=yht;                    % and new height into vector
hAx(2)=axes('position',pos,'color','none');  % second axes with this position an no color
set(hAx(2),'ytick',[])         % clear unwanted ticks from showing...
set(hAx(1),'xticklabel',[])    % clear labels on first x-axis
linkaxes(hAx,'x')              % and synchronize x-axes
grid(hAx(1),'on')              % just a touch

% %%
x = linspace(-2*pi, 2*pi, 100);
y1 = sin(x);
y2 = cos(x);
figure
plot(x, y1, x, y2)

% %%
x = linspace(-2*pi, 2*pi, 100);
y1 = sin(x);
y2 = cos(x);
figure
plot(x, y1, x, y2)
ax = gca;
ax.XAxisLocation = 'origin';
ax.YAxisLocation = 'origin';

% %%
x = 0:0.1:10;
y1 = sin(x);
y2 = cos(x);
plot(x, y1, '-r', 'DisplayName', 'Sine Wave');
hold on;
plot(x, y2, '-b', 'DisplayName', 'Cosine Wave');
hold off;
legend('show');

% %%
plot(1:10)
legend({'$\hat{\psi}$'}, 'Interpreter', 'latex')
title('$\hat{\psi}$', 'Interpreter', 'latex')

% %%
plot(1:10)
legend({'$\hat{\psi}$'}, 'Interpreter', 'latex')
title('Line Plot of Sine and Cosine Between -2\pi and 2\pi')
